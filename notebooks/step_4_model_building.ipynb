# %% [markdown]
# ### Importing Libraries
#
# ---

# %%
import os
import sys
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Custom Seaborn Style
#
# ---

# %%
sns.set_theme('paper')
sns.set_style('ticks')

# %% [markdown]
# ### Adding `utils` to `PYTHONPATH`
#
# ---

# %%
sys.path.append(os.path.abspath("../utils"))

# %% [markdown]
# ### Reading Parquet File
#
# ---

# %%
# Importing load_parquet function from read_data module
from read_data import load_parquet
cars = load_parquet('clean_data', 'clean_data_after_eda.parquet')
cars.head()
# Out:
#    km_driven fuel_type transmission      owner   price  engine_capacity  year  \
# 0      88760    Petrol       Manual  1st owner  219000              998  2012
# 1      17920    Petrol       Manual  1st owner  266000              796  2016
# 2       9940    Petrol       Manual  1st owner  496000             1373  2014
# 3      67340    Petrol       Manual  2nd owner  355000             1199  2016
# 4      30390    Petrol       Manual  1st owner  530000              998  2023
#
#     brand        model
# 0  Maruti  Wagon R 1.0
# 1  Maruti     Alto 800
# 2  Maruti       Ertiga
# 3    Tata        Tiago
# 4  Maruti  New Wagon-R

# %%
# Since we have removed some data while exploratory data analysis,
# Some of the categories in categorical columns might got removed but the category label will still be present
# Because we have converted object datatype into category datatype, so we have to remove these unused categories manually
cat_col = cars.select_dtypes(include='category').columns
for column in cat_col:
    cars[column] = cars[column].cat.remove_unused_categories()

# %% [markdown]
# ### Importing Libraries for Pipeline
#
# ---

# %%
from sklearn.preprocessing import RobustScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import cross_validate, cross_val_predict, KFold, learning_curve, train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### Creating Training and Testing Set
#
# ---

# %%
# Creating Features and Target Variable
X = cars.drop('price', axis=1)
y = cars['price']

# %%
# Splitting Data into Training and Testing Set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Size of Training and Testing Set
print(f"Training Data : {X_train.shape[0]} | Testing Data : {X_test.shape[0]}")
# Out:
# Training Data : 1917 | Testing Data : 639

# %% [markdown]
# ### Handling High Cardinality Column
#
# ---

# %%
# Frequency Distribution of "model" column
# As we can see, "model" column contains huge number of categories, which can cause problem when we apply OneHotEncoding on it
# It will create too many columns and cause sparsity (having too many zeros)
print(f'Unique categories in "model" column : {len(cars['model'].unique())}')
# Out:
# Unique categories in "model" column : 124

# %%
# Compute Frequency Distribution on Training Data to prevent Data Leakage
model_freq = X_train['model'].value_counts(normalize=True)

# %%
# Creating Copy of Training & Testing Set
X_train = X_train.copy()
X_test = X_test.copy()

# %%
# Map Frequency Distribution to Train and Test Separately
X_train['model_freq'] = X_train['model'].map(model_freq).fillna(0)
X_test['model_freq'] = X_test['model'].map(model_freq).fillna(0)

# %%
# Drop Original Model Column
X_train.drop('model', axis=1, inplace=True)
X_test.drop('model', axis=1, inplace=True)

# %% [markdown]
# ### Building Pipeline
#
# ---

# %% [markdown]
# #### Pipeline for Nominal Column

# %%
nominal_cols = ['fuel_type','transmission','brand']

# %%
nominal_trf = Pipeline(steps=[
    ('ohe', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

# %% [markdown]
# #### Pipeline for Ordinal Column

# %%
ordinal_cols = ['owner']

# %%
ordinal_categories = [['Others','3rd owner','2nd owner','1st owner']]

# %%
ordinal_trf = Pipeline(steps=[
    ('oe', OrdinalEncoder(categories=ordinal_categories))
])

# %% [markdown]
# #### Pipeline for Numerical Column

# %%
numerical_cols = ['km_driven','year','engine_capacity']

# %%
numerical_trf = Pipeline(steps=[
    ('scaler', RobustScaler())
])

# %% [markdown]
# #### Adding Everything into ColumnTransformer

# %%
ctf = ColumnTransformer(transformers=[
    ('nominal', nominal_trf, nominal_cols),
    ('ordinal', ordinal_trf, ordinal_cols),
    ('scaling', numerical_trf, numerical_cols)
], remainder='passthrough', n_jobs=-1)

# %% [markdown]
# ### Evaluating Multiple Models
#
# ---

# %%
# Importing Models
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
# Models Dictionary
models = {
    'LR' : LinearRegression(n_jobs=-1),
    'KNN' : KNeighborsRegressor(n_jobs=-1),
    'DT' : DecisionTreeRegressor(random_state=42),
    'RF' : RandomForestRegressor(random_state=42, n_jobs=-1),
    'GB' : GradientBoostingRegressor(random_state=42),
    'XGB' : XGBRegressor(random_state=42, n_jobs=-1)
}

# %%
# Computing Metrics through Cross-Validation
results = {}

for name, model in models.items():
    
    pipe = Pipeline(steps=[
        ('preprocessor', ctf),
        ('model', model)
    ])

    k = KFold(n_splits=5, shuffle=True, random_state=42)

    cv_results = cross_validate(estimator=pipe, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1, return_train_score=False)

    results[name] = {'avg_error': -cv_results['test_mae'].mean(),'avg_score': cv_results['test_r2'].mean()}

    print()
    print(f'Model : {name}')
    print('-'*40)
    print(f'Average Error : {-cv_results['test_mae'].mean():.2f}')
    print(f'Standard Deviation of Error : {cv_results['test_mae'].std():.2f}')
    print(f'Average R2-Score : {cv_results['test_r2'].mean():.2f}')
    print(f'Error Stability (CV of MAE) : {(cv_results['test_mae'].std() / -cv_results['test_mae'].mean()) * 100:.2f}%')
# Out:
# Model : LR
# ----------------------------------------
# Average Error : 123193.35
# Standard Deviation of Error : 6435.48
# Average R2-Score : 0.77
# Error Stability (CV of MAE) : 5.22%
#
# Model : KNN
# ----------------------------------------
# Average Error : 115518.58
# Standard Deviation of Error : 3843.92
# Average R2-Score : 0.79
# Error Stability (CV of MAE) : 3.33%
#
# Model : DT
# ----------------------------------------
# Average Error : 116187.61
# Standard Deviation of Error : 4254.52
# Average R2-Score : 0.76
# Error Stability (CV of MAE) : 3.66%
#
# Model : RF
# ----------------------------------------
# Average Error : 90937.17
# Standard Deviation of Error : 2666.87
# Average R2-Score : 0.86
# Error Stability (CV of MAE) : 2.93%
#
# Model : GB
# ----------------------------------------
# Average Error : 98130.73
# Standard Deviation of Error : 3453.66
# Average R2-Score : 0.85
# Error Stability (CV of MAE) : 3.52%
#
# Model : XGB
# ...

# %%
# Plotting Metric Comparision Graph
results_df = pd.DataFrame(results)

fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(12,8))

sns.barplot(x=results_df.iloc[0,:].sort_values().index.to_list(), y=results_df.iloc[0,:].sort_values().values, ax=ax[0])
ax[0].set_title('Average Error Comparision (Lower is Better)')
ax[0].set_ylabel('Error')
for container in ax[0].containers:
    ax[0].bar_label(container, fmt='%.0f')

sns.barplot(x=results_df.iloc[1,:].sort_values().index.to_list(), y=results_df.iloc[1,:].sort_values().values, ax=ax[1])
ax[1].set_title('Average R2-Score Comparision (Higher is Better)')
ax[1].set_ylabel('R2-Score')
for container in ax[1].containers:
    ax[1].bar_label(container, fmt='%.2f')

plt.tight_layout()
plt.show()

# %%
# Evaluating StackingRegressor (RF + XGB + GB -> ElasticNet meta-learner)
from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import ElasticNet

stack_estimators = [
    ('rf', RandomForestRegressor(random_state=42, n_jobs=-1)),
    ('xgb', XGBRegressor(random_state=42, n_jobs=-1)),
    ('gb', GradientBoostingRegressor(random_state=42))
]

stack_model = StackingRegressor(
    estimators=stack_estimators,
    final_estimator=ElasticNet(random_state=42),
    n_jobs=-1
)

stack_pipe = Pipeline(steps=[
    ('preprocessor', ctf),
    ('model', stack_model)
])

k = KFold(n_splits=5, shuffle=True, random_state=42)

stack_cv_results = cross_validate(estimator=stack_pipe, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1, return_train_score=False)

stack_mae = -stack_cv_results['test_mae'].mean()
stack_std = stack_cv_results['test_mae'].std()
stack_r2 = stack_cv_results['test_r2'].mean()

print(f'Model : StackingRegressor')
print('-'*40)
print(f'Average Error : {stack_mae:.2f}')
print(f'Standard Deviation of Error : {stack_std:.2f}')
print(f'Average R2-Score : {stack_r2:.2f}')
print(f'Error Stability (CV of MAE) : {(stack_std / stack_mae) * 100:.2f}%')
print('')
# Out:
# Model : StackingRegressor
# ----------------------------------------
# Average Error : 87884.49
# Standard Deviation of Error : 1488.70
# Average R2-Score : 0.87
# Error Stability (CV of MAE) : 1.69%

# %% [markdown]
# - The graph shows model performance by average error (lower is better) and average R<sup>2</sup> (higher is better).
# - RandomForestRegressor and XGBRegressor are the top performers (~₹90,900 MAE & R<sup>2</sup> 0.86).
# - A StackingRegressor was also tried, improving MAE by only ~3% (₹87,884 vs ₹90,900) for 3x the model complexity and inference time.
# ```md
#   [StackingRegressor]
#    RF     XGB     GB
#     \      |      /
#      \     |     /
#       \    |    /
#        ▼   ▼   ▼
#       ElasticNet
#     [meta-learner]
#           │
#           ▼
#     Final Prediction
# ```
# - Not worth the trade-off for this project's scope, so **XGBRegressor** is used directly :
#     - It ties RF on error but has the lowest standard deviation of error (XGB's ₹1,913 vs RF's ₹2,667), meaning more consistent predictions across folds.
#     - Being a single model, it's simpler to tune, explain, and serve than a 3-model stack.

# %%
# Creating Object of the Model
xgb = XGBRegressor(random_state=42, n_jobs=-1)

# %%
# Final Pipeline with XGBRegressor
pipe = Pipeline(steps=[
    ('preprocessor', ctf),
    ('model', xgb)
])

# %%
# Computing Metrics through Cross-Validation
cv_results = cross_validate(estimator=pipe, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1)
print(f"Average Error : {-cv_results['test_mae'].mean():.2f}")
print(f"Standard Deviation of Error : {cv_results['test_mae'].std():.2f}")
print(f"Average R2-Score : {cv_results['test_r2'].mean():.2f}")
print(f"Error Stability (CV of MAE) : {(cv_results['test_mae'].std() / -cv_results['test_mae'].mean()) * 100:.2f}%")
# Out:
# Average Error : 90899.92
# Standard Deviation of Error : 1913.66
# Average R2-Score : 0.86
# Error Stability (CV of MAE) : 2.11%

# %% [markdown]
# - XGBRegressor alone gives the same ~₹90,900 MAE, R<sup>2</sup> 0.86 we got in the benchmark above, as expected.
# - Next we'll tune it to see how close we can get to the stacked ensemble's ~₹87,884 MAE without actually adding that complexity.

# %% [markdown]
# ### Performance Evaluation Graphs
#
# ---

# %%
# Fitting the Pipeline
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['fuel_type', 'transmission',
#                                                    'brand']),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('oe',
#                                                                    OrdinalEncoder(categories=[['Others',
#                                                                                                '3rd '
# ...

# %%
# Prediction from Pipeline (Using Cross-Validation)
y_pred = cross_val_predict(estimator=pipe, X=X_train, y=y_train, cv=k, n_jobs=-1)

# %%
# Actual vs Predicted Plot
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()

# %%
# Region with consistent and accurate predictions (Green : price < 15 lakhs)
# Region with more variation in predictions (Red : price > 15 lakhs)
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.axvspan(xmin=y_train.min(), xmax=1500000, alpha=0.25, color='green')
plt.axvspan(xmin=1500000, xmax=y_train.max(), alpha=0.25, color='red')
plt.text(600000, max(y_pred)*0.95, 'High Data Density\n→ Better Accuracy', 
         fontsize=10, color='green')
plt.text(1600000, min(y_pred)*0.95, 'Low Data Density\n→ Higher Error', 
         fontsize=10, color='red')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()

# %%
print(f'Cars with price less than or equal to 15 lakhs : {len(cars[cars['price'] <= 1500000])}')
print(f'Cars with price greater than 15 lakhs : {len(cars[cars['price'] > 1500000])}')
# Out:
# Cars with price less than or equal to 15 lakhs : 2480
# Cars with price greater than 15 lakhs : 76

# %% [markdown]
# - Most points cluster close to the ideal line (y_pred ≈ y_actual), so overall the model is picking up the price structure.
# - Below ₹15L, where most of our data actually is, predictions are tight, makes sense since that's where the model has the most examples to learn from.
# - Above ₹15L, the scatter widens a lot, but we expected this since we don't have many high-value cars in the dataset, so the model has barely seen that range.
# - Not going to read this as the model failing, it's a data-availability gap, more listings above ₹15L would fix it directly.

# %%
# Plotting Learning Curve
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipe, X=X_train, y=y_train, cv=k, shuffle=True, scoring='r2',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, train_scores.mean(axis=1), label='Training R2-Score')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation R2-Score')
plt.fill_between(train_sizes,
                 val_scores.mean(axis=1) - val_scores.std(axis=1),
                 val_scores.mean(axis=1) + val_scores.std(axis=1),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('R2-Score')
plt.title('Learning Curve')
plt.axhline(y=val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Score')
plt.text(train_sizes[-3], (val_scores.mean(axis=1)[-1]+0.01), f'Best Validation Score = {val_scores.mean(axis=1)[-1]:.2f}', color='green', fontsize=10, ha='right')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - Train R<sup>2</sup> sits at ~0.99 basically everywhere, so it's fitting the training data almost perfectly, classic overfitting sign.
# - Validation R<sup>2</sup> starts at ~0.67 with little data and climbs to ~0.86 as we add more, so more data is clearly helping.
# - Big gap between train and validation right now, that's the overfitting we need to fix with tuning.
# - The band around the validation line is shrinking as training size grows, so folds are agreeing more with more data.
# - Curve hasn't flattened out yet at max training size, more data would probably still help, but tuning is the next lever we have.

# %%
# Plotting Learning Curve
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipe, X=X_train, y=y_train, cv=k, shuffle=True, scoring='neg_mean_absolute_error',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, -train_scores.mean(axis=1), label='Training Error')
plt.plot(train_sizes, -val_scores.mean(axis=1), label='Validation Error')
plt.fill_between(train_sizes,
                 -val_scores.mean(axis=1) - (-val_scores.std(axis=1)),
                 -val_scores.mean(axis=1) + (-val_scores.std(axis=1)),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('Error')
plt.title('Learning Curve')
plt.axhline(y=-val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Error')
plt.text(train_sizes[-3], (-val_scores.mean(axis=1)[-1]-6000), f'Best Validation Error = {-val_scores.mean(axis=1)[-1]:.0f}', color='green', fontsize=10, ha='right')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Train error is very low (~₹22,500) and stays flat, confirms the same overfitting story as the R<sup>2</sup> plot.
# - Validation error starts around ₹1,35,000 on little data, drops to ~₹90,300 as training size grows.
# - Gap between train and validation error is wide right now, model is memorizing rather than generalizing.
# - Gap does close as we add more data, so this isn't a dead end, just needs more regularization for now.
# - This gap is exactly why we're tuning next.

# %% [markdown]
# ### Hyperparameter Tuning
#
# ---

# %% [markdown]
# - Both learning curves show a clear gap between train and validation error, so the model is overfitting right now.
# - It fits the training data well but hasn't generalized to unseen data as well as it should.
# - We'll use RandomizedSearchCV to tune XGBRegressor's complexity controls and shrink that gap.
# - We picked random search over a full grid search since it covers enough combinations at a fraction of the compute cost, a good trade-off for the dataset size.

# %%
# Parameter Distribution
param_dist = {
    'model__n_estimators': [200, 300, 400],
    'model__learning_rate': [0.03, 0.05, 0.1],
    'model__max_depth': [2, 3, 4],
    'model__subsample': [0.5, 0.75, 1.0],
    'model__colsample_bytree': [0.5, 0.75, 1.0],
    'model__min_child_weight': [1, 3, 5]
}

# %%
# RandomizedSearchCV Object with Cross-Validation
rcv = RandomizedSearchCV(estimator=pipe, param_distributions=param_dist, cv=k, scoring='neg_mean_absolute_error', n_iter=30, n_jobs=-1, random_state=42)

# %%
# Fitting the RandomizedSearchCV Object
rcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(n_jobs=-1,
#                                                                 remainder='passthrough',
#                                                                 transformers=[('nominal',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                ['fuel_type',
#                                                                                 'transmission',
# ...

# %%
# Best Parameter
rcv.best_params_
# Out:
# {'model__subsample': 0.75,
#  'model__n_estimators': 400,
#  'model__min_child_weight': 1,
#  'model__max_depth': 4,
#  'model__learning_rate': 0.1,
#  'model__colsample_bytree': 1.0}

# %%
# Best Estimator
best_model = rcv.best_estimator_

# %% [markdown]
# ### Performance Evaluation Graphs
#
# ---

# %%
# Computing Metrics through Cross-Validation after Tuning
cv_results = cross_validate(estimator=best_model, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1)
print(f"Average Error : {-cv_results['test_mae'].mean():.2f}")
print(f"Standard Deviation of Error : {cv_results['test_mae'].std():.2f}")
print(f"Average R2-Score : {cv_results['test_r2'].mean():.2f}")
print(f"Error Stability (CV of MAE) : {(cv_results['test_mae'].std() / -cv_results['test_mae'].mean()) * 100:.2f}%")
# Out:
# Average Error : 85281.35
# Standard Deviation of Error : 2426.39
# Average R2-Score : 0.88
# Error Stability (CV of MAE) : 2.85%

# %%
# Fitting the Pipeline
best_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['fuel_type', 'transmission',
#                                                    'brand']),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('oe',
#                                                                    OrdinalEncoder(categories=[['Others',
#                                                                                                '3rd '
# ...

# %%
# Prediction from Pipeline (Using Cross-Validation after Tuning)
y_pred = cross_val_predict(estimator=best_model, X=X_train, y=y_train, cv=k, n_jobs=-1)

# %%
# Calculating the Residuals
residual = y_train - y_pred

# %%
# Actual vs Predicted Plot after Tuning
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price (After Tuning)")
plt.show()

# %% [markdown]
# - Predictions sit closer to the ideal line now, tuning genuinely improved accuracy overall.
# - Below ₹15L, the scatter is noticeably tighter than before, better generalization where we have the most data.
# - Above ₹15L, the spread is only slightly better, still limited by how few high-value cars we have.
# - Makes sense, tuning fixes overfitting but can't make up for data we simply don't have.
# - Overall this is a clear win, and the gains are exactly where we'd expect them, in the price range we actually have data for.

# %%
# Plotting Learning Curve after Tuning
train_sizes, train_scores, val_scores = learning_curve(
    estimator=best_model, X=X_train, y=y_train, cv=k, shuffle=True, scoring='r2',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, train_scores.mean(axis=1), label='Training R2-Score')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation R2-Score')
plt.fill_between(train_sizes,
                 val_scores.mean(axis=1) - val_scores.std(axis=1),
                 val_scores.mean(axis=1) + val_scores.std(axis=1),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('R2-Score')
plt.title('Learning Curve (After Tuning)')
plt.axhline(y=val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Score')
plt.text(train_sizes[-3], (val_scores.mean(axis=1)[-1]+0.01), f'Best Validation Score = {val_scores.mean(axis=1)[-1]:.2f}', color='green', fontsize=10, ha='right')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - Train R<sup>2</sup> now settles at ~0.97-0.98, down from ~0.99 pre-tuning, so we're overfitting less.
# - Validation R<sup>2</sup> climbs smoothly to a best of ~0.88, up from ~0.86 before tuning.
# - Train/validation gap is visibly narrower now, better bias-variance balance.
# - The band around the validation curve is tighter at larger training sizes too, folds agree more.
# - Curve still hasn't fully plateaued, more data would likely push this further, but tuning already got us a real improvement.

# %%
# Plotting Learning Curve after Tuning
train_sizes, train_scores, val_scores = learning_curve(
    estimator=best_model, X=X_train, y=y_train, cv=k, shuffle=True, scoring='neg_mean_absolute_error',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, -train_scores.mean(axis=1), label='Training Error')
plt.plot(train_sizes, -val_scores.mean(axis=1), label='Validation Error')
plt.fill_between(train_sizes,
                 -val_scores.mean(axis=1) - (-val_scores.std(axis=1)),
                 -val_scores.mean(axis=1) + (-val_scores.std(axis=1)),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('Error')
plt.title('Learning Curve (After Tuning)')
plt.axhline(y=-val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Error')
plt.text(train_sizes[-3], (-val_scores.mean(axis=1)[-1]-6000), f'Best Validation Error = {-val_scores.mean(axis=1)[-1]:.0f}', color='green', fontsize=10, ha='right')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Train error now settles at ~₹43,000, up from ~₹22,500 pre-tuning, expected since we deliberately regularized the model.
# - Validation error drops to a best of ~₹86,350, improved from ~₹90,300 before tuning.
# - Train/validation gap is narrower than before, model is generalizing better, not just memorizing.
# - Validation curve is smoother and more consistent across training sizes than pre-tuning too.
# - Still hasn't flattened out completely, so more data would likely help further, but this is a solid, real improvement from tuning alone.

# %% [markdown]
# ### Final Model Evaluation on Unseen Data
#
# ---

# %%
# Model Performance on Unseen Data
y_pred_test = best_model.predict(X_test)

# %%
# Mean Absolute Error and R2-Score on Unseen Data
from sklearn.metrics import mean_absolute_error, r2_score
print(f'Mean Absolute Error on Unseen Data : {mean_absolute_error(y_test, y_pred_test):.2f}')
print(f'R2-Score on Unseen Data : {r2_score(y_test, y_pred_test):.2f}')
# Out:
# Mean Absolute Error on Unseen Data : 87723.02
# R2-Score on Unseen Data : 0.87

# %%
# Mean Absolute Percentage Error on Unseen Data
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred_test)
print(f'Mean Absolute Percentage Error on Unseen Data : {mape * 100:.2f}%')
# Out:
# Mean Absolute Percentage Error on Unseen Data : 13.93%

# %% [markdown]
# - On the holdout test set, we get MAE of ₹87,723 and R<sup>2</sup> of 0.87, close to our tuned CV numbers (MAE of ₹85,281, R<sup>2</sup> of 0.88),
# - So the model is generalizing, not just overfit to the training folds.
# - The small gap (~3% higher MAE on holdout vs CV) is expected, holdout is data the model never saw at all during tuning.
# - MAPE comes out to ~14%, this is the number that actually means something to a buyer/seller i.e. "expect our estimate to be off by about 14% on average."

# %% [markdown]
# ### Predicting a Price Range (Quantile Models)
#
# ---

# %% [markdown]
# - A single point prediction isn't very useful for a buyer/seller on its own, a range is more practical.
# - We first tried a flat `pred ± MAE` range, but that's flawed, MAE is one global average, so it doesn't scale with price.
# - For cheap cars, `pred - MAE` can go negative, and for expensive cars the range ends up unrealistically tight.
# - Instead, we train two extra `GradientBoostingRegressor` models directly on the 10th and 90th percentile of price.
# - This gives us a lower and upper bound that scales naturally with the predicted price and can't go negative for realistic inputs.

# %%
# Importing GradientBoostingRegressor for Quantile Regression
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Lower Bound Pipeline (10th Percentile)
lower_pipe = Pipeline(steps=[
    ('preprocessor', ctf),
    ('model', GradientBoostingRegressor(loss='quantile', alpha=0.1, random_state=42))
])

# Upper Bound Pipeline (90th Percentile)
upper_pipe = Pipeline(steps=[
    ('preprocessor', ctf),
    ('model', GradientBoostingRegressor(loss='quantile', alpha=0.9, random_state=42))
])

# %%
# Fitting Both Quantile Pipelines on Training Data
lower_pipe.fit(X_train, y_train)
upper_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['fuel_type', 'transmission',
#                                                    'brand']),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('oe',
#                                                                    OrdinalEncoder(categories=[['Others',
#                                                                                                '3rd '
# ...

# %%
# Predicting Lower and Upper Bounds on Unseen Data
y_pred_lower = lower_pipe.predict(X_test)
y_pred_upper = upper_pipe.predict(X_test)

# Clamping Lower Bound at 0 as a Safety Net (Price can never be Negative)
y_pred_lower = np.clip(y_pred_lower, a_min=0, a_max=None)

# %%
# Coverage : % of Actual Prices that Fall within the Predicted Range
coverage = np.mean((y_test >= y_pred_lower) & (y_test <= y_pred_upper))

# Sanity Check : Lower Bound should always be less than or equal to Upper Bound
valid_range = np.mean(y_pred_lower <= y_pred_upper)

print(f'Coverage (Actual Price within Predicted Range) : {coverage * 100:.2f}%')
print(f'Valid Ranges (Lower <= Upper) : {valid_range * 100:.2f}%')
print(f'Negative Lower Bounds before Clipping : {(lower_pipe.predict(X_test) < 0).sum()}')
# Out:
# Coverage (Actual Price within Predicted Range) : 77.62%
# Valid Ranges (Lower <= Upper) : 100.00%
# Negative Lower Bounds before Clipping : 0

# %% [markdown]
# - Coverage came out to ~77.6%, meaning about 77.6% of actual test-set prices fell inside our predicted range.
# - Valid ranges are 100%, so the lower bound was never above the upper bound for any prediction, the quantile models never crossed each other.
# - And 0 lower bounds were negative even before we applied the clip, so on this dataset the safety-net clamp is precautionary, it never actually had to kick in.
# - The range scales with price and gives an honest sense of uncertainty, which was the actual goal.

# %% [markdown]
# ### Exporting Final Pipeline and Model Frequency as Pickle File
#
# ---

# %%
# Importing create_path function from file_locator module
from file_locator import create_path

# %%
# Creating Model Frequency Dictionary
model_freq_dict = model_freq.to_dict()

# %%
# Exporting Model Frequency as Pickle File
with open(create_path('models','model_freq.pkl'), 'wb') as file:
    pickle.dump(model_freq_dict, file)

# %%
# Exporting Best Model as Pickle File
with open(create_path('models','pipe.pkl'), 'wb') as file:
    pickle.dump(best_model, file)

# %%
# Exporting Lower Bound Pipeline as Pickle File
with open(create_path('models','lower_pipe.pkl'), 'wb') as file:
    pickle.dump(lower_pipe, file)

# %%
# Exporting Upper Bound Pipeline as Pickle File
with open(create_path('models','upper_pipe.pkl'), 'wb') as file:
    pickle.dump(upper_pipe, file)
