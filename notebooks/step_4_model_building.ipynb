# %% [markdown]
# ### Importing Libraries
#
# ---

# %%
import os
import sys
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Custom Seaborn Style
#
# ---

# %%
sns.set_theme('paper')
sns.set_style('ticks')

# %% [markdown]
# ### Adding `utils` to `PYTHONPATH`
#
# ---

# %%
sys.path.append(os.path.abspath("../utils"))

# %% [markdown]
# ### Reading Parquet File
#
# ---

# %%
# Importing load_parquet function from read_data module
from read_data import load_parquet
cars = load_parquet('clean_data', 'clean_data_after_eda.parquet')
cars.head()
# Out:
#    km_driven fuel_type transmission      owner   price  engine_capacity  year  \
# 0      88760    Petrol       Manual  1st owner  219000              998  2012
# 1      17920    Petrol       Manual  1st owner  266000              796  2016
# 2       9940    Petrol       Manual  1st owner  496000             1373  2014
# 3      67340    Petrol       Manual  2nd owner  355000             1199  2016
# 4      30390    Petrol       Manual  1st owner  530000              998  2023
#
#     brand        model
# 0  Maruti  Wagon R 1.0
# 1  Maruti     Alto 800
# 2  Maruti       Ertiga
# 3    Tata        Tiago
# 4  Maruti  New Wagon-R

# %%
# Since we have removed some data while exploratory data analysis,
# Some of the categories in categorical columns might got removed but the category will still be present
# Because we have converted object datatype into category datatype, so we have to remove these unused categories manually
cat_col = cars.select_dtypes(include='category').columns
for column in cat_col:
    cars[column] = cars[column].cat.remove_unused_categories()

# %% [markdown]
# ### Importing Libraries for Pipeline
#
# ---

# %%
from sklearn.preprocessing import RobustScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_validate, cross_val_predict, KFold, learning_curve, train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import StackingRegressor

# %% [markdown]
# ### Creating Training and Testing Set
#
# ---

# %%
# Creating Features and Target Variable
X = cars.drop('price', axis=1)
y = cars['price']

# %%
# Splitting Data into Training and Testing Set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Size of Training and Testing Set
print(f"Training Data : {X_train.shape[0]} | Testing Data : {X_test.shape[0]}")
# Out:
# Training Data : 1917 | Testing Data : 639

# %% [markdown]
# ### Handling High Cardinality Column
#
# ---

# %%
# Frequency Distribution of "model" column
# As we can see, "model" column contains huge number of categories, which can cause problem when we apply OneHotEncoding on it
# It will create too many columns and cause sparsity (having too many zeros)
print(f'Unique categories in "model" column : {len(cars['model'].unique())}')
# Out:
# Unique categories in "model" column : 124

# %%
# Compute Frequency Distribution on Training Data to prevent Data Leakage
model_freq = X_train['model'].value_counts(normalize=True)

# %%
# Creating Copy of Training & Testing Set
X_train = X_train.copy()
X_test = X_test.copy()

# %%
# Map Frequency Distribution to Train and Test Separately
X_train['model_freq'] = X_train['model'].map(model_freq).fillna(0)
X_test['model_freq'] = X_test['model'].map(model_freq).fillna(0)

# %%
# Drop Original Model Column
X_train.drop('model', axis=1, inplace=True)
X_test.drop('model', axis=1, inplace=True)

# %% [markdown]
# ### Building Pipeline
#
# ---

# %% [markdown]
# #### Component for Nominal Column

# %%
nominal_cols = ['fuel_type','transmission','brand']

# %%
nominal_trf = Pipeline(steps=[
    ('ohe', OneHotEncoder(sparse_output=False, handle_unknown='ignore'))
])

# %% [markdown]
# #### Component for Ordinal Column

# %%
ordinal_cols = ['owner']

# %%
ordinal_categories = [['Others','3rd owner','2nd owner','1st owner']]

# %%
ordinal_trf = Pipeline(steps=[
    ('oe', OrdinalEncoder(categories=ordinal_categories))
])

# %% [markdown]
# #### Component for Numerical Column

# %%
numerical_cols = ['km_driven','year','engine_capacity']

# %%
numerical_trf = Pipeline(steps=[
    ('scaler', RobustScaler())
])

# %% [markdown]
# #### Adding Everything into ColumnTransformer

# %%
ctf = ColumnTransformer(transformers=[
    ('nominal', nominal_trf, nominal_cols),
    ('ordinal', ordinal_trf, ordinal_cols),
    ('scaling', numerical_trf, numerical_cols)
], remainder='passthrough', n_jobs=-1)

# %% [markdown]
# ### Evaluating Multiple Models
#
# ---

# %%
# Importing Models
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
# Models Dictionary
models = {
    'LR' : LinearRegression(n_jobs=-1),
    'KNN' : KNeighborsRegressor(n_jobs=-1),
    'DT' : DecisionTreeRegressor(random_state=42),
    'RF' : RandomForestRegressor(random_state=42, n_jobs=-1),
    'GB' : GradientBoostingRegressor(random_state=42),
    'XGB' : XGBRegressor(random_state=42, n_jobs=-1)
}

# %%
# Computing Average Error and R2-Score through Cross-Validation
results = {}

for name, model in models.items():
    
    pipe = Pipeline(steps=[
        ('preprocessor', ctf),
        ('model', model)
    ])

    k = KFold(n_splits=5, shuffle=True, random_state=42)

    cv_results = cross_validate(estimator=pipe, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1, return_train_score=False)

    results[name] = {'avg_error': -cv_results['test_mae'].mean(),'avg_score': cv_results['test_r2'].mean()}

    print()
    print(f'Model : {name}')
    print('-'*40)
    print(f'Average Error : {-cv_results['test_mae'].mean():.2f}')
    print(f'Standard Deviation of Error : {cv_results['test_mae'].std():.2f}')
    print(f'Average R2-Score : {cv_results['test_r2'].mean():.2f}')
    print(f'Standard Deviation of R2-Score : {cv_results['test_r2'].std():.2f}')
# Out:
# Model : LR
# ----------------------------------------
# Average Error : 123193.35
# Standard Deviation of Error : 6435.48
# Average R2-Score : 0.77
# Standard Deviation of R2-Score : 0.01
#
# Model : KNN
# ----------------------------------------
# Average Error : 115518.58
# Standard Deviation of Error : 3843.92
# Average R2-Score : 0.79
# Standard Deviation of R2-Score : 0.00
#
# Model : DT
# ----------------------------------------
# Average Error : 116187.61
# Standard Deviation of Error : 4254.52
# Average R2-Score : 0.76
# Standard Deviation of R2-Score : 0.03
#
# Model : RF
# ----------------------------------------
# Average Error : 90937.17
# Standard Deviation of Error : 2666.87
# Average R2-Score : 0.86
# Standard Deviation of R2-Score : 0.01
#
# Model : GB
# ----------------------------------------
# Average Error : 98200.66
# Standard Deviation of Error : 3416.36
# Average R2-Score : 0.85
# Standard Deviation of R2-Score : 0.01
#
# Model : XGB
# ----------------------------------------
# Average Error : 91845.00
# Standard Deviation of Error : 2955.45
# Average R2-Score : 0.86
# Standard Deviation of R2-Score : 0.02

# %%
# Plotting Metric Comparision Graph
results_df = pd.DataFrame(results)

fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(12,8))

sns.barplot(x=results_df.iloc[0,:].sort_values().index.to_list(), y=results_df.iloc[0,:].sort_values().values, ax=ax[0])
ax[0].set_title('Average Error Comparision (Lower is Better)')
ax[0].set_ylabel('Error')
for container in ax[0].containers:
    ax[0].bar_label(container, fmt='%.0f')

sns.barplot(x=results_df.iloc[1,:].sort_values().index.to_list(), y=results_df.iloc[1,:].sort_values().values, ax=ax[1])
ax[1].set_title('Average R2-Score Comparision (Higher is Better)')
ax[1].set_ylabel('R2-Score')
for container in ax[1].containers:
    ax[1].bar_label(container, fmt='%.2f')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Creating Stacking Regressor
#
# ---

# %% [markdown]
# - The above graph shows model performance based on average error (lower is better) and average R<sup>2</sup> (higher is better).
# - RandomForestRegressor, XGBRegressor, and GradientBoostingRegressor are the top-performing models :
#     - RF achieves the lowest error and highest R<sup>2</sup>.
#     - XGB and GB closely follow with strong performance on both metrics.
# - To leverage their strengths, (RF + XGB + GB) are used as base models in a StackingRegressor :
#     - RF captures non-linearities and complex feature interactions effectively.
#     - XGB and GB reduce bias and variance through gradient boosting, improving predictive power.
#     - Combining all three captures a wider range of patterns than any single model alone.
# - ElasticNet is used as the final estimator because :
#     - It combines L1 and L2 regularization, balancing feature selection and coefficient shrinkage to improve generalization.
# - This stacked approach produces a more robust and accurate predictive model than any individual base model.

# %%
# Creating Object of the Models
rf = RandomForestRegressor(random_state=42, n_jobs=-1)
gb = GradientBoostingRegressor(random_state=42)
xgb = XGBRegressor(random_state=42, n_jobs=-1)
meta_model = ElasticNet(max_iter=10000, random_state=42)

# %%
# Assigning Base Model for StackingRegressor
base_model = [('rf', rf),('xgb', xgb),('gb', gb)]

# %%
# Structure of StackingRegressor
stack = StackingRegressor(
    estimators=base_model, 
    final_estimator=meta_model, 
    passthrough=False, 
    cv=k, n_jobs=-1
)

# %%
# Final Pipeline with StackingRegressor
pipe = Pipeline(steps=[
    ('preprocessor', ctf), 
    ('model', stack) 
])

# %%
# Average Error and R2-Score through Cross-Validation
cv_results = cross_validate(estimator=pipe, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1)
print(f"Average Error : {-cv_results['test_mae'].mean():.2f}")
print(f"Standard Deviation of Error : {cv_results['test_mae'].std():.2f}")
print(f"Average R2-Score : {cv_results['test_r2'].mean():.2f}")
print(f"Standard Deviation of R2-Score : {cv_results['test_r2'].std():.2f}")
# Out:
# Average Error : 88265.66
# Standard Deviation of Error : 1838.92
# Average R2-Score : 0.87
# Standard Deviation of R2-Score : 0.01

# %% [markdown]
# - StackingRegressor outperforms all individual models tested in the benchmark.
# - The stacked ensemble (RF + XGB + GB + ElasticNet) achieves an average error of ₹88,266, lower than the best individual model (RF at ₹90,937).
# - It is the most consistent model across folds, with a standard deviation of error of ₹1,839, the lowest of all models tested.
# - It explains variance well with an average R<sup>2</sup> of 0.87, matching the top individual models while being more stable fold-to-fold.

# %% [markdown]
# ### Performance Evaluation Graphs
#
# ---

# %%
# Fitting the Pipeline
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['fuel_type', 'transmission',
#                                                    'brand']),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('oe',
#                                                                    OrdinalEncoder(categories=[['Others',
#                                                                                                '3rd '
#                                                                                                'owner',
#                                                                                                '2nd '
#                                                                                                'owner',
#                                                                                                '1st '
#                                                                                                'owner']]))]),
#                                                   ['o...
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=None,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=None,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None, ...)),
#                                                ('gb',
#                                                 GradientBoostingRegressor(random_state=42))],
#                                    final_estimator=ElasticNet(max_iter=10000,
#                                                               random_state=42),
#                                    n_jobs=-1))])

# %%
# Prediction from Pipeline (Using Cross-Validation)
y_pred = cross_val_predict(estimator=pipe, X=X_train, y=y_train, cv=k, n_jobs=-1)

# %%
# Actual vs Predicted Plot
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()

# %%
# Region with consistent and accurate predictions (Green : price < 15 lakhs)
# Region with more variation in predictions (Red : price > 15 lakhs)
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.axvspan(xmin=y_train.min(), xmax=1500000, alpha=0.25, color='green')
plt.axvspan(xmin=1500000, xmax=y_train.max(), alpha=0.25, color='red')
plt.text(600000, max(y_pred)*0.95, 'High Data Density\n→ Better Accuracy', 
         fontsize=10, color='green')
plt.text(1600000, min(y_pred)*0.95, 'Low Data Density\n→ Higher Error', 
         fontsize=10, color='red')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price")
plt.show()

# %%
print(f'Cars with price less than or equal to 15 lakhs : {len(cars[cars['price'] <= 1500000])}')
print(f'Cars with price greater than 15 lakhs : {len(cars[cars['price'] > 1500000])}')
# Out:
# Cars with price less than or equal to 15 lakhs : 2480
# Cars with price greater than 15 lakhs : 76

# %% [markdown]
# - Most predictions cluster closely around the ideal line (y_pred ≈ y_actual), confirming the model captures the overall price structure well.
# - In the lower to mid-price range (below ₹15L), where data density is highest, predictions are tight and consistent, the model has learned this segment well.
# - Prediction error increases noticeably above ₹15L, where data density drops sharply, this is expected behavior, not a model failure.
# - With very few examples of high-value cars, the model lacks signal to learn their pricing patterns, leading to wider scatter and higher variance in that range.
# - This is a data limitation, not a modeling one, more listings in the ₹15L+ range would directly reduce error in that segment.

# %%
# Plotting Learning Curve
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipe, X=X_train, y=y_train, cv=k, shuffle=True, scoring='r2',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, train_scores.mean(axis=1), label='Training R2-Score')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation R2-Score')
plt.fill_between(train_sizes,
                 val_scores.mean(axis=1) - val_scores.std(axis=1),
                 val_scores.mean(axis=1) + val_scores.std(axis=1),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('R2-Score')
plt.title('Learning Curve')
plt.axhline(y=val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Score')
plt.text(train_sizes[-3], (val_scores.mean(axis=1)[-1]+0.01), f'Best Validation Score = {val_scores.mean(axis=1)[-1]:.2f}', color='green', fontsize=10, ha='right')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - The training R<sup>2</sup> remains consistently high (≈0.96–0.97) across all training sizes, indicating the model fits training data very well.
# - The validation R<sup>2</sup> starts low (≈0.74) with limited data but improves steadily as training size increases, reaching a best validation score of 0.87.
# - The gap between training and validation scores narrows as more data is added, showing the model is gradually overfitting less and generalizing better.
# - The confidence band around the validation curve shrinks with more training data, indicating more stable and consistent performance across folds.
# - The validation curve has not fully plateaued at the largest training size, suggesting the model would likely benefit from additional data.

# %%
# Plotting Learning Curve
train_sizes, train_scores, val_scores = learning_curve(
    estimator=pipe, X=X_train, y=y_train, cv=k, shuffle=True, scoring='neg_mean_absolute_error',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, -train_scores.mean(axis=1), label='Training Error')
plt.plot(train_sizes, -val_scores.mean(axis=1), label='Validation Error')
plt.fill_between(train_sizes,
                 -val_scores.mean(axis=1) - (-val_scores.std(axis=1)),
                 -val_scores.mean(axis=1) + (-val_scores.std(axis=1)),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('Error')
plt.title('Learning Curve')
plt.axhline(y=-val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Error')
plt.text(train_sizes[-3], (-val_scores.mean(axis=1)[-1]-6000), f'Best Validation Error = {-val_scores.mean(axis=1)[-1]:.0f}', color='green', fontsize=10, ha='right')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - Training error starts low (≈₹55,000) and flattens quickly, confirming the model fits training data very well across all training sizes.
# - Validation error starts high (≈₹1,25,000) with limited data and decreases steadily as training size increases, reaching a best validation error of ₹87,750.
# - The large gap between training and validation error signals overfitting, the model learns training patterns well but struggles to generalize with less data.
# - The gap narrows as training size grows, showing that more data directly reduces overfitting and improves generalization.
# - The confidence band around the validation curve shrinks with more data, indicating more consistent and stable performance across folds.
# - The validation error curve has not fully flattened at the largest training size, suggesting more data would likely push performance further.

# %% [markdown]
# ### Hyperparameter Tuning
#
# ---

# %% [markdown]
# - The learning curves reveal a clear gap between training and validation error, indicating mild overfitting.
# - The model fits training data well but hasn't fully generalized.
# - To reduce this gap, RandomizedSearchCV is used to tune the complexity controls across all three base models and the meta-model.
# - RandomizedSearchCV samples random combinations from this grid, balancing search coverage against compute cost on a dataset of this size.

# %%
# Parameter Distribution
param_dist = {
    'model__rf__n_estimators': [200, 300],
    'model__rf__max_depth': [10, 20],
    'model__rf__min_samples_leaf': [3, 5],
    'model__rf__min_samples_split': [5, 7],
    'model__xgb__n_estimators': [200, 300],
    'model__xgb__learning_rate': [0.05, 0.1],
    'model__xgb__max_depth': [2, 4],
    'model__xgb__subsample': [0.5, 0.75],
    'model__xgb__colsample_bytree': [0.5, 0.75],
    'model__gb__n_estimators': [100, 200],   
    'model__gb__learning_rate': [0.05, 0.1],  
    'model__gb__max_depth': [2, 4],       
    'model__gb__subsample': [0.5, 0.75],
    'model__final_estimator__alpha': [0.1, 10.0],
    'model__final_estimator__l1_ratio': [0.0, 1.0]
}

# %%
# RandomizedSearchCV Object with Cross-Validation
rcv = RandomizedSearchCV(estimator=pipe, param_distributions=param_dist, cv=k, scoring='neg_mean_absolute_error', n_iter=30, n_jobs=-1, random_state=42)

# %%
# Fitting the RandomizedSearchCV Object
rcv.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(n_jobs=-1,
#                                                                 remainder='passthrough',
#                                                                 transformers=[('nominal',
#                                                                                Pipeline(steps=[('ohe',
#                                                                                                 OneHotEncoder(handle_unknown='ignore',
#                                                                                                               sparse_output=False))]),
#                                                                                ['fuel_type',
#                                                                                 'transmission',
#                                                                                 'brand']),
#                                                                               ('ordinal',
#                                                                                Pipeline(steps=[('oe',
#                                                                                                 Ordina...
#                                         'model__rf__max_depth': [10, 20],
#                                         'model__rf__min_samples_leaf': [3, 5],
#                                         'model__rf__min_samples_split': [5, 7],
#                                         'model__rf__n_estimators': [200, 300],
#                                         'model__xgb__colsample_bytree': [0.5,
#                                                                          0.75],
#                                         'model__xgb__learning_rate': [0.05,
#                                                                       0.1],
#                                         'model__xgb__max_depth': [2, 4],
#                                         'model__xgb__n_estimators': [200, 300],
#                                         'model__xgb__subsample': [0.5, 0.75]},
#                    random_state=42, scoring='neg_mean_absolute_error')

# %%
# Best Parameter
rcv.best_params_
# Out:
# {'model__xgb__subsample': 0.5,
#  'model__xgb__n_estimators': 300,
#  'model__xgb__max_depth': 4,
#  'model__xgb__learning_rate': 0.1,
#  'model__xgb__colsample_bytree': 0.5,
#  'model__rf__n_estimators': 200,
#  'model__rf__min_samples_split': 5,
#  'model__rf__min_samples_leaf': 3,
#  'model__rf__max_depth': 20,
#  'model__gb__subsample': 0.5,
#  'model__gb__n_estimators': 200,
#  'model__gb__max_depth': 2,
#  'model__gb__learning_rate': 0.1,
#  'model__final_estimator__l1_ratio': 0.0,
#  'model__final_estimator__alpha': 0.1}

# %%
# Best Estimator
best_model = rcv.best_estimator_

# %% [markdown]
# ### Performance Evaluation Graphs
#
# ---

# %%
# Average Error and R2-Score through Cross-Validation after Tuning
cv_results = cross_validate(estimator=best_model, X=X_train, y=y_train, cv=k, scoring={'mae':'neg_mean_absolute_error','r2':'r2'}, n_jobs=-1)
print(f"Average Error : {-cv_results['test_mae'].mean():.2f}")
print(f"Standard Deviation of Error : {cv_results['test_mae'].std():.2f}")
print(f"Average R2-Score : {cv_results['test_r2'].mean():.2f}")
print(f"Standard Deviation of R2-Score : {cv_results['test_r2'].std():.2f}")
# Out:
# Average Error : 85308.59
# Standard Deviation of Error : 2320.79
# Average R2-Score : 0.88
# Standard Deviation of R2-Score : 0.01

# %%
# Fitting the Pipeline
best_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('nominal',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['fuel_type', 'transmission',
#                                                    'brand']),
#                                                  ('ordinal',
#                                                   Pipeline(steps=[('oe',
#                                                                    OrdinalEncoder(categories=[['Others',
#                                                                                                '3rd '
#                                                                                                'owner',
#                                                                                                '2nd '
#                                                                                                'owner',
#                                                                                                '1st '
#                                                                                                'owner']]))]),
#                                                   ['o...
#                                                              max_depth=4,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=300,
#                                                              n_jobs=-1,
#                                                              num_parallel_tree=None, ...)),
#                                                ('gb',
#                                                 GradientBoostingRegressor(max_depth=2,
#                                                                           n_estimators=200,
#                                                                           random_state=42,
#                                                                           subsample=0.5))],
#                                    final_estimator=ElasticNet(alpha=0.1,
#                                                               l1_ratio=0.0,
#                                                               max_iter=10000,
#                                                               random_state=42),
#                                    n_jobs=-1))])

# %%
# Prediction from Pipeline (Using Cross-Validation after Tuning)
y_pred = cross_val_predict(estimator=best_model, X=X_train, y=y_train, cv=k, n_jobs=-1)

# %%
# Calculating the Residuals
residual = y_train - y_pred

# %%
# Actual vs Predicted Plot after Tuning
plt.scatter(y_train, y_pred, alpha=0.4)
plt.plot([y_train.min(), y_train.max()], [y_pred.min(), y_pred.max()], color='red', linestyle='--')
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Price (After Tuning)")
plt.show()

# %% [markdown]
# - After tuning, predictions align more closely with the ideal line (y_pred ≈ y_actual), confirming improved model accuracy overall.
# - In the lower to mid-price range (below ₹15L), the scatter is noticeably tighter, indicating better generalization in the high-density data region.
# - Above ₹15L, deviation remains, the spread is slightly reduced compared to before tuning.
# - But high-value cars still show greater prediction variance due to limited training data in that segment.
# - The improvement in the high-price range is marginal, which is expected.
# - Hyperparameter tuning reduces overfitting but cannot compensate for sparse data in that segment.
# - Overall, tuning has produced a more accurate and better-calibrated model, with the clearest gains visible in the price range where data is most abundant.

# %%
# Plotting Learning Curve after Tuning
train_sizes, train_scores, val_scores = learning_curve(
    estimator=best_model, X=X_train, y=y_train, cv=k, shuffle=True, scoring='r2',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, train_scores.mean(axis=1), label='Training R2-Score')
plt.plot(train_sizes, val_scores.mean(axis=1), label='Validation R2-Score')
plt.fill_between(train_sizes,
                 val_scores.mean(axis=1) - val_scores.std(axis=1),
                 val_scores.mean(axis=1) + val_scores.std(axis=1),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('R2-Score')
plt.title('Learning Curve (After Tuning)')
plt.axhline(y=val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Score')
plt.text(train_sizes[-3], (val_scores.mean(axis=1)[-1]+0.01), f'Best Validation Score = {val_scores.mean(axis=1)[-1]:.2f}', color='green', fontsize=10, ha='right')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - After tuning, the training R<sup>2</sup> settles at ≈0.96 (down from ≈0.97 pre-tuning) and remains stable across all training sizes.
# - The model is less complex and fits training data more realistically.
# - The validation R<sup>2</sup> shows a smooth, consistent upward trend, reaching a best validation score of 0.88, compared to 0.87 before tuning.
# - The gap between training and validation scores is visibly narrower after tuning, confirming better generalization and an improved bias-variance balance.
# - The confidence band around the validation curve is tighter at larger training sizes, indicating more stable and consistent performance across folds.
# - The validation curve has not fully plateaued at ~1,500 samples, suggesting the model would continue to improve with more training data.
# - A stronger signal than the pre-tuning curve, which flattened earlier.
# - Overall, tuning produced a model that generalizes more reliably, with a clearer and more consistent path to its best validation score.

# %%
# Plotting Learning Curve after Tuning
train_sizes, train_scores, val_scores = learning_curve(
    estimator=best_model, X=X_train, y=y_train, cv=k, shuffle=True, scoring='neg_mean_absolute_error',
    train_sizes=np.linspace(0.1, 1.0, 5), random_state=42, n_jobs=-1
)

# %%
plt.plot(train_sizes, -train_scores.mean(axis=1), label='Training Error')
plt.plot(train_sizes, -val_scores.mean(axis=1), label='Validation Error')
plt.fill_between(train_sizes,
                 -val_scores.mean(axis=1) - (-val_scores.std(axis=1)),
                 -val_scores.mean(axis=1) + (-val_scores.std(axis=1)),
                 alpha=0.2)
plt.xlabel('Training Set Size')
plt.ylabel('Error')
plt.title('Learning Curve (After Tuning)')
plt.axhline(y=-val_scores.mean(axis=1)[-1], color='green', linestyle='--', label='Best Validation Error')
plt.text(train_sizes[-3], (-val_scores.mean(axis=1)[-1]-6000), f'Best Validation Error = {-val_scores.mean(axis=1)[-1]:.0f}', color='green', fontsize=10, ha='right')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# - After tuning, the training error settles at ≈₹55,000–58,000 and remains relatively stable across training sizes, indicating the model is well-regularized.
# - The validation error starts high (≈₹1,23,000) with limited data and decreases steadily, reaching a best validation error of ₹85,819 at ~1,500 samples.
# - The gap between training and validation error is narrower compared to pre-tuning, confirming better generalization and a healthier bias-variance balance.
# - The confidence band around the validation curve is tighter, especially at larger training sizes, indicating more consistent and stable performance across folds.
# - The validation error curve decreases more smoothly after tuning, showing the model responds more consistently to additional training data.
# - The validation curve has not fully flattened at ~1,500 samples, suggesting further improvement is likely with more data.

# %% [markdown]
# ### Final Model Evaluation on Unseen Data
#
# ---

# %%
# Model Performance on Unseen Data
y_pred_test = best_model.predict(X_test)

# %%
# Mean Absolute Error and R2-Score on Unseen Data
from sklearn.metrics import mean_absolute_error, r2_score
print(f'Mean Absolute Error on Unseen Data : {mean_absolute_error(y_test, y_pred_test):.2f}')
print(f'R2-Score on Unseen Data : {r2_score(y_test, y_pred_test):.2f}')
# Out:
# Mean Absolute Error on Unseen Data : 88313.38
# R2-Score on Unseen Data : 0.88

# %% [markdown]
# ### Exporting Final Pipeline and Model Frequency as Pickle File
#
# ---

# %%
# Importing create_path function from file_locator module
from file_locator import create_path

# %%
# Creating Model Frequency Dictionary
model_freq_dict = model_freq.to_dict()

# %%
# Exporting Model Frequency as Pickle File
with open(create_path('models','model_freq.pkl'), 'wb') as file:
    pickle.dump(model_freq_dict, file)

# %%
# Exporting Best Model as Pickle File
with open(create_path('models','pipe.pkl'), 'wb') as file:
    pickle.dump(best_model, file)
